# %% [markdown]
# Max and Daddy Maths
#
# For learning about graphs and equations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10,10,100)
y = 2*x

#plt.plot(x, y, '-r', label='y=2x')
#plt.plot(x, -3*x, '-b', label='y=-3x')
plt.plot(x, x, '-g', label='y=x')
#plt.plot(x, (3*x)+2, '-r', label='y=3x+2')
#plt.plot(x, x*x, '-b', label='y=x^2')
#plt.plot(x, (x*x)-4, '-r', label='y=x^2-4')
#plt.plot(x, x*x*x, '-b', label='y=x^3')
plt.title('Graph of y=x')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper left')
plt.grid()
plt.show()
