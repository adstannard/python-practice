# %% [markdown]
# <a href="https://colab.research.google.com/github/adstannard/python-practice/blob/master/chick-rabbits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We count 35 heads and 94 legs among the chickens and rabbits in a farm. How many rabbits and how many chickens do we have?
# Write a function to solve the problem.
#
# chickens_rabbits(35,94) would return ‘23 chickens and 12 rabbits

# %%
def chicken_rabbits(heads,legs):
  rabbits = ((legs - (2 * heads))/2)
  chicken = heads - rabbits
  if rabbits % 1 == 0 and rabbits > -1 and chicken > -1:
    return print(' Rabbits:',int(rabbits),'\n','Chicken:',int(chicken))
  else:
    return print('No solution')

# %%
chicken_rabbits(35,94)
# Out:
#  Rabbits: 12
#  Chicken: 23

# %%
for i in range(10,17):
  print('\n head',i,'\n')
  for j in range((2 * i),(5 * i)):
    chicken_rabbits(i,j)
# Out:
#  head 10
#
#  Rabbits: 0
#  Chicken: 10
#  Rabbits: 1
#  Chicken: 9
#  Rabbits: 2
#  Chicken: 8
#  Rabbits: 3
#  Chicken: 7
#  Rabbits: 4
#  Chicken: 6
#  Rabbits: 5
#  Chicken: 5
#  Rabbits: 6
#  Chicken: 4
#  Rabbits: 7
#  Chicken: 3
#  Rabbits: 8
#  Chicken: 2
#  Rabbits: 9
#  Chicken: 1
#  Rabbits: 10
#  Chicken: 0
#
#  head 11
#
#  Rabbits: 0
#  Chicken: 11
#  Rabbits: 1
#  Chicken: 10
#  Rabbits: 2
#  Chicken: 9
#  Rabbits: 3
#  Chicken: 8
#  Rabbits: 4
#  Chicken: 7
#  Rabbits: 5
#  Chicken: 6
#  Rabbits: 6
#  Chicken: 5
#  Rabbits: 7
#  Chicken: 4
#  Rabbits: 8
#  Chicken: 3
#  Rabbits: 9
#  Chicken: 2
#  Rabbits: 10
#  Chicken: 1
#  Rabbits: 11
#  Chicken: 0
#
#  head 12
#
#  Rabbits: 0
#  Chicken: 12
#  Rabbits: 1
#  Chicken: 11
#  Rabbits: 2
#  Chicken: 10
#  Rabbits: 3
#  Chicken: 9
#  Rabbits: 4
#  Chicken: 8
#  Rabbits: 5
#  Chicken: 7
#  Rabbits: 6
#  Chicken: 6
#  Rabbits: 7
#  Chicken: 5
#  Rabbits: 8
#  Chicken: 4
#  Rabbits: 9
#  Chicken: 3
#  Rabbits: 10
# ...
