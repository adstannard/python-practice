# %% [markdown]
# Evelyn and Daddy
# Maths Graph practice

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10,10,100)
y = 2*x

#plt.plot(x, y, '-r', label='y=2x')
#plt.plot(x, -3*x, '-b', label='y=-3x')
#plt.plot(x, x, '-b', label='y=x')
#plt.plot(x, -1*x, '-r', label='y=-x')
#plt.plot(x, (3*x)+2, '-r', label='y=3x+2')
#plt.plot(x, x*x, '-b', label='y=x^2')
#plt.plot(x, x*x*x*x, '-r', label='y=x^4')
#plt.plot(x, (x*x)+10, '-r', label='y=x^2+10')
#plt.plot(x, (x*x)-10, '-y', label='y=x^2-10')
plt.plot(x, (x*x)+(3*x)-3, '-r', label='y=x^2+3x-3')
# plt.plot(x, x*x*x, '-g', label='y=x^3')
plt.title('Graph of y=x')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper left')
plt.grid()
plt.show()
